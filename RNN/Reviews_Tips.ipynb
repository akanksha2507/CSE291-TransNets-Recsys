# %%
import pandas as pd
import numpy as np

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf8')

# %%
file_path = '/Users/Maverick/Workspace/Fall_17/Rec_Sys/Project/dataset/'

# %%
review_data = pd.read_json(file_path + 'review.json', lines=True)

# %%
review_data.head()
# Out:
#               business_id  cool       date  funny               review_id  \
# 0  uYHaNptLzDLoV_JZ_MuzUA     0 2016-07-12      0  VfBHSwC5Vz_pbFluy07i9Q
# 1  uYHaNptLzDLoV_JZ_MuzUA     0 2016-10-02      0  3zRpneRKDsOPq92tq7ybAA
# 2  uYHaNptLzDLoV_JZ_MuzUA     0 2015-09-17      0  ne5WhI1jUFOcRn-b-gAzHA
# 3  uYHaNptLzDLoV_JZ_MuzUA     0 2016-08-21      0  llmdwOgDReucVoWEry61Lw
# 4  uYHaNptLzDLoV_JZ_MuzUA     0 2013-11-20      0  DuffS87NaSMDmIfluvT83g
#
#    stars                                               text  useful  \
# 0      5  My girlfriend and I stayed here for 3 nights a...       0
# 1      3  If you need an inexpensive place to stay for a...       0
# 2      3  Mittlerweile gibt es in Edinburgh zwei Ableger...       0
# 3      4  Location is everything and this hotel has it! ...       0
# 4      5  gute lage im stadtzentrum. shoppingmeile und s...       0
#
#                   user_id
# 0  cjpdDjZyprfyDG3RlkVG3w
# 1  bjTcT8Ty4cJZhEOEo01FGA
# 2  AXgRULmWcME7J6Ix3I--ww
# ...

# %%
tips_data = pd.read_json(file_path + 'tip.json', lines = True)

# %%
tips_data.head()
# Out:
#               business_id       date  likes  \
# 0  tJRDll5yqpZwehenzE2cSg 2012-07-15      0
# 1  jH19V2I9fIslnNhDzPmdkA 2015-08-12      0
# 2  dAa0hB2yrnHzVmsCkN4YvQ 2014-06-20      0
# 3  dAa0hB2yrnHzVmsCkN4YvQ 2016-10-12      0
# 4  ESzO3Av0b1_TzKOiqzbQYQ 2017-01-28      0
#
#                                                 text                 user_id
# 0              Get here early enough to have dinner.  zcTZk7OG8ovAmh_fenH21g
# 1  Great breakfast large portions and friendly wa...  ZcLKXikTHYOnYt5VYRO5sg
# 2  Nice place. Great staff.  A fixture in the tow...  oaYhjqBbh18ZhU0bpyzSuw
# 3                     Happy hour 5-7 Monday - Friday  ulQ8Nyj7jCUR8M83SUMoRQ
# 4  Parking is a premium, keep circling, you will ...  ulQ8Nyj7jCUR8M83SUMoRQ

# %%
review_tips_all = pd.merge(review_data, tips_data, on = ['business_id','user_id'])

# %%
review_tips_all.head()
# Out:
#               business_id  cool     date_x  funny               review_id  \
# 0  uYHaNptLzDLoV_JZ_MuzUA     0 2016-08-21      0  llmdwOgDReucVoWEry61Lw
# 1  uYHaNptLzDLoV_JZ_MuzUA     0 2016-08-21      0  llmdwOgDReucVoWEry61Lw
# 2  uYHaNptLzDLoV_JZ_MuzUA     0 2016-08-21      0  llmdwOgDReucVoWEry61Lw
# 3  uYHaNptLzDLoV_JZ_MuzUA     0 2013-07-07      0  cUgvEy5wj7zYE68v1BzzVg
# 4  uYHaNptLzDLoV_JZ_MuzUA     0 2015-04-13      0  dhl3ZW9aAEX_T7_um5tfaQ
#
#    stars                                             text_x  useful  \
# 0      4  Location is everything and this hotel has it! ...       0
# 1      4  Location is everything and this hotel has it! ...       0
# 2      4  Location is everything and this hotel has it! ...       0
# 3      4  This is a fairly new property I think. It is a...       0
# 4      4  Location location location! \n\nMotel One is j...       2
#
#                   user_id     date_y  likes  \
# 0  oU2SSOmsp_A8JYI7Z2JJ5w 2016-08-18      0
# ...

# %%
review_tips_req = review_tips_all.loc[:,['text_x','text_y']]

# %%
review_tips_req.columns = ['reviews','tips']

# %%
review_tips_req
# Out:
#                                                   reviews  \
# 0       Location is everything and this hotel has it! ...
# 1       Location is everything and this hotel has it! ...
# 2       Location is everything and this hotel has it! ...
# 3       This is a fairly new property I think. It is a...
# 4       Location location location! \n\nMotel One is j...
# 5       Everything was good except Thai chicken wraps....
# 6       I love Pei Wei. The food is delicious. The atm...
# 7       Service is fast and on time. Love the online o...
# 8       What can I say, I'm a sucker for Pei Wei.  Whe...
# 9       What can I say, I'm a sucker for Pei Wei.  Whe...
# 10      What can I say, I'm a sucker for Pei Wei.  Whe...
# 11      What can I say, I'm a sucker for Pei Wei.  Whe...
# 12      What can I say, I'm a sucker for Pei Wei.  Whe...
# 13      What can I say, I'm a sucker for Pei Wei.  Whe...
# 14      What can I say, I'm a sucker for Pei Wei.  Whe...
# ...

# %%
# Saving the dataframe

review_tips_req.to_csv('review_tips.csv')
